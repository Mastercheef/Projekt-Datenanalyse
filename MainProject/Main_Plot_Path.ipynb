# %%
import pandas as pd

from Builder import simulation_test,subset, plotter, plot_cut
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')
sns.set_context('notebook',font_scale=1)

# %%
data = simulation_test(S=1.0, T=1, r=0.02, m=0, v=0.035, l=10, step=1000, Npaths=1, sigma=0.35,N=1)
# Out:
# Jumps                 14
# Anomaly Returns IF    14
# CutOff Return          8
# CutOff RSV             8
# CutOff Diff            8
# dtype: int64
# -----------------------------
# CutOF with Diff: 4 of 14 anomalies were recognized ->  29.0 %
# Diff: 4 of 14 anomalies were recognized -> 29.0 %
# RSV : 6 of 14 anomalies were recognized -> 43.0 %
# -----------------------------
# IF Return:  0.429
# Cutoff Return:  0.421
# ---------------------
# IF Diff:  0.296
# Cutoff Diff:  0.364
# ---------------------
# IF RSV:  0.429
# Cutoff RSV:  0.421
# ---------------------
# IF RSV diff:  0.357
# IF Return RSV diff:  0.357
# ---------------------

# %%
plotter(data)

# %%
plot_cut(data,'Return log')
