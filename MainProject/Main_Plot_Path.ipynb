# %%
import pandas as pd

from Builder import simulation_test,subset, plotter, plot_cut
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')
sns.set_context('notebook',font_scale=1)

# %%
data = simulation_test(S=1.0, T=1, r=0.02, m=0, v=0.04, l=10, step=1000, Npaths=1, sigma=0.35,N=1)
# Out:
# Jumps                  8
# Anomaly Returns IF    10
# CutOff Return          2
# CutOff RSV             2
# CutOff Diff            2
# dtype: int64
# -----------------------------
# CutOF with Diff: 2 of 8 anomalies were recognized ->  25.0 %
# Diff: 3 of 8 anomalies were recognized -> 38.0 %
# RSV : 5 of 8 anomalies were recognized -> 62.0 %
# -----------------------------
# IF Return:  0.556
# Cutoff Return:  0.556
# ---------------------
# IF Diff:  0.333
# Cutoff Diff:  0.4
# ---------------------
# IF RSV:  0.556
# Cutoff RSV:  0.556
# ---------------------
# IF RSV diff:  0.444
# IF Return RSV diff:  0.444
# ---------------------

# %%
plotter(data)

# %%
plot_cut(data,'Return log')
