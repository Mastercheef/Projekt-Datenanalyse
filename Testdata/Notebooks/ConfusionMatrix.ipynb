# %%
from sklearn.metrics import f1_score
import Testdata.Builder as Builder

# %% [markdown]
# ### Compare IF vs CutOff
#
# Using the confusionsmatrix, the results of the IF with the RSV feature are compared with the CutOff with RSV feature.

# %%
data = Builder.simulation_test(v=0.055, l=10, step=1000, sigma=0.35,N=1,print_f1=True)
# Out:
# Anomaly merton: 0 of 11 anomalies (0.0 %) in total: 10
# -----------------------------
# Anomaly Returns IF: 7 of 11 anomalies (64.0 %) in total: 10
# -----------------------------
# Anomaly RSV IF: 7 of 11 anomalies (64.0 %) in total: 10
# -----------------------------
# Anomaly Diff IF: 5 of 11 anomalies (45.0 %) in total: 10
# -----------------------------
# Amomaly RSV Diff: 7 of 11 anomalies (64.0 %) in total: 10
# -----------------------------
# Amomaly Returns RSV Diff: 7 of 11 anomalies (64.0 %) in total: 10
# -----------------------------
# Cutoff Jump: 6 of 11 anomalies (55.0 %) in total: 9
# -----------------------------
# CutOff Return: 6 of 11 anomalies (55.0 %) in total: 9
# -----------------------------
# CutOff RSV: 6 of 11 anomalies (55.0 %) in total: 9
# -----------------------------
# CutOff Diff: 6 of 11 anomalies (55.0 %) in total: 9
# -----------------------------
# IF Return:  0.667
# Cutoff Return:  0.737
# ---------------------
# IF Diff:  0.476
# Cutoff Diff:  0.6
# ---------------------
# IF RSV:  0.667
# Cutoff RSV:  0.737
# ---------------------
# IF RSV diff:  0.667
# IF Return RSV diff:  0.667
# ---------------------

# %% [markdown]
# ### IF with RSV

# %%
print(Builder.class_report(data,'Anomaly RSV IF'))
print('F1 rsv iff: ', f1_score(data['Jumps'], data['Anomaly RSV IF']))
# Out:
#               precision    recall  f1-score   support
#
#       normal       1.00      1.00      1.00       989
#      outlier       0.70      0.64      0.67        11
#
#     accuracy                           0.99      1000
#    macro avg       0.85      0.82      0.83      1000
# weighted avg       0.99      0.99      0.99      1000
#
# None
# F1 rsv iff:  0.6666666666666666

# %%
cm = Builder.calc_confusion_matrix(data,'Anomaly RSV IF')
Builder.plot_confusion_matrix(cm)

# %% [markdown]
# ### CutOff with RSV

# %%
print('CutOff RSV:')
Builder.class_report(data,'CutOff RSV')
# Out:
# CutOff RSV:
#               precision    recall  f1-score   support
#
#       normal       0.99      1.00      1.00       989
#      outlier       0.67      0.55      0.60        11
#
#     accuracy                           0.99      1000
#    macro avg       0.83      0.77      0.80      1000
# weighted avg       0.99      0.99      0.99      1000

# %%
cm = Builder.calc_confusion_matrix(data,'CutOff RSV')
Builder.plot_confusion_matrix(cm)
