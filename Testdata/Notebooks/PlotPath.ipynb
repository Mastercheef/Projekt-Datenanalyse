# %%
import pandas as pd

from Builder import simulation_test, plotter, plot_cut
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')
sns.set_context('notebook',font_scale=1)

# %%
data = simulation_test(S=1.0, T=1, r=0.02, m=0, v=0.055, l=10, step=1000, Npaths=1, sigma=0.68,N=1)
# Out:
# Anomaly merton: 0 of 10 anomalies (0.0 %) in total: 10
# -----------------------------
# Anomaly Returns IF: 4 of 10 anomalies (40.0 %) in total: 10
# -----------------------------
# Anomaly RSV IF: 4 of 10 anomalies (40.0 %) in total: 10
# -----------------------------
# Anomaly Diff IF: 3 of 10 anomalies (30.0 %) in total: 10
# -----------------------------
# Amomaly RSV Diff: 3 of 10 anomalies (30.0 %) in total: 10
# -----------------------------
# Amomaly Returns RSV Diff: 4 of 10 anomalies (40.0 %) in total: 10
# -----------------------------
# Cutoff Jump: 4 of 10 anomalies (40.0 %) in total: 12
# -----------------------------
# CutOff Return: 4 of 10 anomalies (40.0 %) in total: 12
# -----------------------------
# CutOff RSV: 4 of 10 anomalies (40.0 %) in total: 12
# -----------------------------
# CutOff Diff: 4 of 10 anomalies (40.0 %) in total: 12
# -----------------------------

# %%
plotter(data)

# %%
#plot_cut(data,'Return log')
