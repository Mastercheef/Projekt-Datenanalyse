# %%
from Testdata.Builder import simulation_test, plotter, plot_cut
# %matplotlib inline

# %% [markdown]
# ### Merton Jump Diffusion Model
#
#
# Erstelle eine zufällige Zeitreihe mit markierten Sprüngen.
# Wobei (v) die Standartabweichung der Sprünge ist, (l) die intensität der Sprünge und (sigma) die Standartabweichung des Wiener processes.

# %%
data = simulation_test(v=0.035, l=10, step=1000, sigma=0.25,N=1)
# Out:
# Anomaly merton: 0 of 12 anomalies (0.0 %) in total: 10
# -----------------------------
# Anomaly Returns IF: 6 of 12 anomalies (50.0 %) in total: 10
# -----------------------------
# Anomaly RSV IF: 6 of 12 anomalies (50.0 %) in total: 10
# -----------------------------
# Anomaly Diff IF: 6 of 12 anomalies (50.0 %) in total: 10
# -----------------------------
# Amomaly RSV Diff: 6 of 12 anomalies (50.0 %) in total: 10
# -----------------------------
# Amomaly Returns RSV Diff: 6 of 12 anomalies (50.0 %) in total: 10
# -----------------------------
# Cutoff Jump: 6 of 12 anomalies (50.0 %) in total: 8
# -----------------------------
# CutOff Return: 6 of 12 anomalies (50.0 %) in total: 8
# -----------------------------
# CutOff RSV: 6 of 12 anomalies (50.0 %) in total: 8
# -----------------------------
# CutOff Diff: 6 of 12 anomalies (50.0 %) in total: 8
# -----------------------------

# %% [markdown]
# ### Ausgabe der Zeitreihe
#
# Darstellung der Zeitreihe mit markierten Sprüngen und erkannten Anomalien mit dem Isolation Forest und Merkmalen.

# %%
plotter(data)

# %% [markdown]
# ### Ausgabe CutOff

# %%
plot_cut(data,'Return log')
