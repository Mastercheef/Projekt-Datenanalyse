# %%
from Stocks.StocksLoader import *
from Stocks.BuilderStock import *
from Stocks.PlotterStock import plot_signed_anomaly, plotter

# %% [markdown]
# Example notebook to show how the built system works on real futures data.

# %%
futures =  ['GC=F','CL=F','SI=F','ZS=F','KC=F','ZC=F']
labels = futures

# %%
futures_stock = Stocks(futures, labels, start="2014-01-01", stop="2021-10-01")
futures_stock = futures_stock.df_stocks.dropna()
futures_stock
# Out:
# Stock Ticker         GC=F                                                  \
# Stock Info           Open         High          Low        Close   Volume
# Date
# 2013-12-31    1196.400024  1212.400024  1182.000000  1201.900024    124.0
# 2014-01-02    1204.300049  1227.300049  1204.300049  1225.000000    209.0
# 2014-01-03    1221.699951  1239.000000  1221.699951  1238.400024    142.0
# 2014-01-06    1232.800049  1247.000000  1221.900024  1237.800049    127.0
# 2014-01-07    1239.300049  1242.400024  1226.300049  1229.400024     73.0
# ...                   ...          ...          ...          ...      ...
# 2021-09-24    1749.699951  1749.699951  1745.000000  1749.699951     76.0
# 2021-09-27    1751.699951  1754.400024  1747.500000  1750.000000    808.0
# 2021-09-28    1739.599976  1741.699951  1726.800049  1735.800049  15748.0
# 2021-09-29    1732.400024  1744.099976  1721.400024  1721.500000   6634.0
# 2021-09-30    1725.500000  1760.300049  1724.500000  1755.300049    997.0
#
# ...

# %%
for label in labels:
    stockDf = pd.DataFrame(futures_stock[label]['Close'])
    df = build_stock(stockDf,N=1,contamin=0.008)
    plotter(df,label,False)
# Out:
# C:\Users\eaut2\anaconda3\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
