# %%
import matplotlib.pyplot as plt
import pandas as pd

from create_jump_paths import *
from IsolationForest.isolatin_forest import *

# %%
path = test_data()

# %%
path.plot_path_jumps()

# %%
path.returns
# Out:
#           pct   log_ret
# 1    0.007822  0.007791
# 2   -0.002234 -0.002237
# 3   -0.006982 -0.007007
# 4   -0.011073 -0.011135
# 5   -0.002866 -0.002870
# ..        ...       ...
# 995 -0.004989 -0.005002
# 996 -0.005376 -0.005390
# 997  0.004866  0.004854
# 998  0.008719  0.008681
# 999  0.000723  0.000723
#
# [999 rows x 2 columns]

# %%
path.rv
# Out:
#            RV
# 2    0.000066
# 3    0.000054
# 4    0.000173
# 5    0.000132
# 6    0.000127
# ..        ...
# 995  0.000305
# 996  0.000054
# 997  0.000053
# 998  0.000099
# 999  0.000076
#
# [998 rows x 1 columns]

# %%
forest = i_f(path.data_df)
# Out:
# {'behaviour': 'deprecated', 'bootstrap': False, 'contamination': 0.1, 'max_features': 1.0, 'max_samples': 'auto', 'n_estimators': 50, 'n_jobs': None, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %%
forest.plot_if_jumps()

# %%
path.plot_variations()
